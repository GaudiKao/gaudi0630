# %%
#1家分店30天的營收
import numpy as np
one_store = np.random.randint(100, 10000, size=(30,))
one_store
# Out:
# array([8455, 5930, 1128, 6501, 8401, 9617, 6533,  447, 9207, 1933, 5844,
#        2953, 1916, 9055, 2294, 9796, 3100, 3764, 8011, 5880, 2289,  759,
#        1611, 3672, 8045, 7790, 1805, 4027, 8111, 6993], dtype=int32)

# %%
#累計每天這家店的營收
oneStoreCum = one_store.cumsum()
oneStoreCum
# Out:
# array([  8455,  14385,  15513,  22014,  30415,  40032,  46565,  47012,
#         56219,  58152,  63996,  66949,  68865,  77920,  80214,  90010,
#         93110,  96874, 104885, 110765, 113054, 113813, 115424, 119096,
#        127141, 134931, 136736, 140763, 148874, 155867])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), oneStoreCum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
